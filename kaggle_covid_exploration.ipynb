# %% [markdown]
# <a href="https://colab.research.google.com/github/katarzynasornat/basics/blob/master/kaggle_covid_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib.patches import Rectangle

# %%
image_df = pd.read_csv("/train_image_level.csv")
study_df = pd.read_csv("/train_study_level.csv")

# %%
image_study_joined =

# %%
image_df.loc[image_df.id == '29e17eb29c38_image', "label"].tolist()
# Out:
# ['opacity 1 214.65209 1364.89829 766.5807500000001 1736.79872 opacity 1 1517.48799 1305.67848 2043.35993 1658.62857']

# %%
study_df.loc[study_df.id == '000c9c05fd14_study', ]
# Out:
#                    id  ...  Atypical Appearance
# 1  000c9c05fd14_study  ...                    1
#
# [1 rows x 5 columns]

# %%
ds1 = pydicom.dcmread('/var/images/29e17eb29c38.dcm')
plt.imshow(ds1.pixel_array, cmap=plt.cm.bone)
# Get the current reference
ax = plt.gca()

# Create a Rectangle patch
rect = Rectangle((214.65209,1364.89829),551.92866,371.90043,linewidth=1,edgecolor='r',facecolor='none')
rect1 = Rectangle((1517.48799,1305.67848),525.87194,352.95009,linewidth=1,edgecolor='r',facecolor='none')
# Add the patch to the Axes
ax.add_patch(rect)
ax.add_patch(rect1)

# %%
image_df.loc[image_df.id == '29e17eb29c38_image', "boxes"].values[0]
# Out:
# "[{'x': 214.65209, 'y': 1364.89829, 'width': 551.92866, 'height': 371.90043}, {'x': 1517.48799, 'y': 1305.67848, 'width': 525.87194, 'height': 352.95009}]"

# %%
image_df[image_df.id == '51759b5579bc_image']
# Out:
#                       id boxes           label StudyInstanceUID
# 2010  51759b5579bc_image   NaN  none 1 0 0 1 1     000c9c05fd14

# %%
ds1 = pydicom.dcmread('/var/images/51759b5579bc.dcm')
plt.imshow(ds1.pixel_array, cmap=plt.cm.bone)
